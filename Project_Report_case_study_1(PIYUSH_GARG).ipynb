# %%
# %%html
# <hr style = "height : 2px; background-color: lightgray;">
# <center> <h1> BASIC CERTIFICATION COURSE IN ARTIFICIAL INTELLIGENCE </h1></center>
# <center> <h2> Case Study 1 </h2></center>
# <center> <h2> Analysis of Treatment Quality and Efficiency of Hospitals </h2></center>
# <b>Submitted by :PIYUSH GARG
#  <hr style = "height : 2px; background-color: gray;">
# Out:
# <hr style = "height : 2px; background-color: lightgray;">
# <center> <h1> BASIC CERTIFICATION COURSE IN ARTIFICIAL INTELLIGENCE </h1></center>
# <center> <h2> Case Study 1 </h2></center>
# <center> <h2> Analysis of Treatment Quality and Efficiency of Hospitals </h2></center>
# <b>Submitted by :PIYUSH GARG
#  <hr style = "height : 2px; background-color: gray;">

# %%
from google.colab import files
df = files.upload()
# Out:
#      <input type="file" id="files-c76c34d8-6e66-4198-a317-b6ce13b649a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c76c34d8-6e66-4198-a317-b6ce13b649a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('sparcs1 (1) - sparcs1 (1).csv')
df
# Out:
#       Health Service Area Hospital County  Operating Certificate Number  \
# 0           New York City       Manhattan                     7002054.0
# 1           New York City       Manhattan                     7002054.0
# 2           New York City       Manhattan                     7002054.0
# 3           Southern Tier        Tompkins                     5401001.0
# 4           New York City           Bronx                     7000014.0
# ...                   ...             ...                           ...
# 19994       New York City       Manhattan                     7002024.0
# 19995       New York City       Manhattan                     7002024.0
# 19996       New York City       Manhattan                     7002024.0
# 19997       New York City       Manhattan                     7002024.0
# 19998       New York City       Manhattan                     7002024.0
#
#        Facility ID Age Group Length of Stay Type of Admission  \
# ...

# %%
df.shape
# Out:
# (19999, 13)

# %%
df.head()
# Out:
#   Health Service Area Hospital County  Operating Certificate Number  \
# 0       New York City       Manhattan                     7002054.0
# 1       New York City       Manhattan                     7002054.0
# 2       New York City       Manhattan                     7002054.0
# 3       Southern Tier        Tompkins                     5401001.0
# 4       New York City           Bronx                     7000014.0
#
#    Facility ID Age Group Length of Stay Type of Admission  \
# 0       1458.0   0 to 17              2           Newborn
# 1       1458.0   0 to 17              4         Emergency
# 2       1464.0   0 to 17              2           Newborn
# 3        977.0   0 to 17              2           Newborn
# 4       1176.0   0 to 17              3         Emergency
#
#                     Patient Disposition CCS Procedure Description  \
# 0                     Home or Self Care              CIRCUMCISION
# 1  Cancer Center or Children's Hospital    RESP INTUB/MECH VENTIL
# ...

# %%
df.columns
# Out:
# Index(['Health Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Facility ID', 'Age Group',
#        'Length of Stay', 'Type of Admission', 'Patient Disposition',
#        'CCS Procedure Description', 'APR Severity of Illness Code',
#        'APR Risk of Mortality', 'Source of Payment 1', 'Total Costs'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Operating Certificate Number   Facility ID  \
# count                  1.999400e+04  19994.000000
# mean                   6.968105e+06   1574.881414
# std                    3.611114e+05    570.057810
# min                    1.010000e+05      1.000000
# 25%                    7.002017e+06   1450.000000
# 50%                    7.002032e+06   1458.000000
# 75%                    7.002054e+06   1464.000000
# max                    7.004010e+06   3975.000000
#
#        APR Severity of Illness Code
# count                  19999.000000
# mean                       1.382419
# std                        0.669259
# min                        0.000000
# 25%                        1.000000
# 50%                        1.000000
# 75%                        2.000000
# max                        4.000000

# %%
df.drop(['Operating Certificate Number'], axis = 1, inplace = True)
df.head()
# Out:
#   Health Service Area Hospital County  Facility ID Age Group Length of Stay  \
# 0       New York City       Manhattan       1458.0   0 to 17              2
# 1       New York City       Manhattan       1458.0   0 to 17              4
# 2       New York City       Manhattan       1464.0   0 to 17              2
# 3       Southern Tier        Tompkins        977.0   0 to 17              2
# 4       New York City           Bronx       1176.0   0 to 17              3
#
#   Type of Admission                   Patient Disposition  \
# 0           Newborn                     Home or Self Care
# 1         Emergency  Cancer Center or Children's Hospital
# 2           Newborn                     Home or Self Care
# 3           Newborn                     Home or Self Care
# 4         Emergency                     Home or Self Care
#
#   CCS Procedure Description  APR Severity of Illness Code  \
# 0              CIRCUMCISION                             1
# ...

# %%
df.drop(['Total Costs'], axis = 1, inplace = True)
df.head()
# Out:
#   Health Service Area Hospital County  Facility ID Age Group Length of Stay  \
# 0       New York City       Manhattan       1458.0   0 to 17              2
# 1       New York City       Manhattan       1458.0   0 to 17              4
# 2       New York City       Manhattan       1464.0   0 to 17              2
# 3       Southern Tier        Tompkins        977.0   0 to 17              2
# 4       New York City           Bronx       1176.0   0 to 17              3
#
#   Type of Admission                   Patient Disposition  \
# 0           Newborn                     Home or Self Care
# 1         Emergency  Cancer Center or Children's Hospital
# 2           Newborn                     Home or Self Care
# 3           Newborn                     Home or Self Care
# 4         Emergency                     Home or Self Care
#
#   CCS Procedure Description  APR Severity of Illness Code  \
# 0              CIRCUMCISION                             1
# ...

# %%
df.drop(['Hospital County'], axis = 1, inplace = True)
df.head()
# Out:
#   Health Service Area  Facility ID Age Group Length of Stay Type of Admission  \
# 0       New York City       1458.0   0 to 17              2           Newborn
# 1       New York City       1458.0   0 to 17              4         Emergency
# 2       New York City       1464.0   0 to 17              2           Newborn
# 3       Southern Tier        977.0   0 to 17              2           Newborn
# 4       New York City       1176.0   0 to 17              3         Emergency
#
#                     Patient Disposition CCS Procedure Description  \
# 0                     Home or Self Care              CIRCUMCISION
# 1  Cancer Center or Children's Hospital    RESP INTUB/MECH VENTIL
# 2                     Home or Self Care    OPHTHALM-/OT-OLOGIC DX
# 3                     Home or Self Care   PROPHYLACTIC VAC/INOCUL
# 4                     Home or Self Care     DIAGNOSTIC SPINAL TAP
#
#    APR Severity of Illness Code APR Risk of Mortality Source of Payment 1
# ...

# %%
df.drop(['Health Service Area'], axis = 1, inplace = True)
df.head()
# Out:
#    Facility ID Age Group Length of Stay Type of Admission  \
# 0       1458.0   0 to 17              2           Newborn
# 1       1458.0   0 to 17              4         Emergency
# 2       1464.0   0 to 17              2           Newborn
# 3        977.0   0 to 17              2           Newborn
# 4       1176.0   0 to 17              3         Emergency
#
#                     Patient Disposition CCS Procedure Description  \
# 0                     Home or Self Care              CIRCUMCISION
# 1  Cancer Center or Children's Hospital    RESP INTUB/MECH VENTIL
# 2                     Home or Self Care    OPHTHALM-/OT-OLOGIC DX
# 3                     Home or Self Care   PROPHYLACTIC VAC/INOCUL
# 4                     Home or Self Care     DIAGNOSTIC SPINAL TAP
#
#    APR Severity of Illness Code APR Risk of Mortality Source of Payment 1
# 0                             1                 Minor   Insurance Company
# ...

# %%
print("dimension of sparcs data: {}".format(df.shape))
# Out:
# dimension of sparcs data: (19999, 9)

# %%
df.isnull().sum()
# Out:
# Facility ID                     5
# Age Group                       0
# Length of Stay                  0
# Type of Admission               0
# Patient Disposition             4
# CCS Procedure Description       0
# APR Severity of Illness Code    0
# APR Risk of Mortality           3
# Source of Payment 1             0
# dtype: int64

# %%
df=df.dropna(subset=['Facility ID','Patient Disposition','APR Risk of Mortality'])

# %%
df.isnull().sum()
# Out:
# Facility ID                     0
# Age Group                       0
# Length of Stay                  0
# Type of Admission               0
# Patient Disposition             0
# CCS Procedure Description       0
# APR Severity of Illness Code    0
# APR Risk of Mortality           0
# Source of Payment 1             0
# dtype: int64

# %%
print(df.groupby('Type of Admission').size())
# Out:
# Type of Admission
# Elective          1280
# Emergency         5453
# Newborn          12774
# Not Available        6
# Urgent             474
# dtype: int64

# %%
import seaborn as sns
sns.countplot(x=df['Type of Admission'],label="Count")
# Out:
# <Axes: xlabel='Type of Admission', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19987 entries, 0 to 19998
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Facility ID                   19987 non-null  float64
#  1   Age Group                     19987 non-null  object
#  2   Length of Stay                19987 non-null  object
#  3   Type of Admission             19987 non-null  object
#  4   Patient Disposition           19987 non-null  object
#  5   CCS Procedure Description     19987 non-null  object
#  6   APR Severity of Illness Code  19987 non-null  int64
#  7   APR Risk of Mortality         19987 non-null  object
#  8   Source of Payment 1           19987 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.5+ MB

# %%
df.apply(lambda cols : cols.unique() )
# Out:
# Facility ID                     [1458.0, 1464.0, 977.0, 1176.0, 1302.0, 1306.0...
# Age Group                       [0 to 17, 18 to 29, 30 to 49, 70 or Older, 50 ...
# Length of Stay                  [2, 4, 3, 15, 1, 35, 5, 8, 6, 16, 7, 23, 11, 2...
# Type of Admission               [Newborn, Emergency, Elective, Urgent, Not Ava...
# Patient Disposition             [Home or Self Care, Cancer Center or Children'...
# CCS Procedure Description       [CIRCUMCISION, RESP INTUB/MECH VENTIL, OPHTHAL...
# APR Severity of Illness Code                                         [1, 2, 3, 4]
# APR Risk of Mortality                           [Minor, Major, Moderate, Extreme]
# Source of Payment 1             [Insurance Company, Blue Cross, Self-Pay, Medi...
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()
df["Type of Admission"]=le.fit_transform(df["Type of Admission"])
# Out:
# <ipython-input-22-933a5e8dde46>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Type of Admission"]=le.fit_transform(df["Type of Admission"])

# %%
print(df["Type of Admission"])
# Out:
# 0        2
# 1        1
# 2        2
# 3        2
# 4        1
#         ..
# 19994    2
# 19995    2
# 19996    2
# 19997    2
# 19998    2
# Name: Type of Admission, Length: 19987, dtype: int64

# %%
le= LabelEncoder()
df["CCS Procedure Description"]=le.fit_transform(df["CCS Procedure Description"])
print(df["CCS Procedure Description"])
# Out:
# 0         22
# 1        171
# 2         94
# 3        163
# 4         32
#         ...
# 19994     94
# 19995    154
# 19996     94
# 19997     94
# 19998     94
# Name: CCS Procedure Description, Length: 19987, dtype: int64
# <ipython-input-24-54bd7299b0ff>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CCS Procedure Description"]=le.fit_transform(df["CCS Procedure Description"])

# %%
le= LabelEncoder()
df["APR Risk of Mortality"]=le.fit_transform(df["APR Risk of Mortality"])
print(df["APR Risk of Mortality"])
# Out:
# 0        2
# 1        1
# 2        2
# 3        2
# 4        2
#         ..
# 19994    2
# 19995    2
# 19996    2
# 19997    2
# 19998    2
# Name: APR Risk of Mortality, Length: 19987, dtype: int64
# <ipython-input-25-785317eada06>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["APR Risk of Mortality"]=le.fit_transform(df["APR Risk of Mortality"])

# %%
le= LabelEncoder()
df["Age Group"]=le.fit_transform(df["Age Group"])
print(df["Age Group"])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19994    0
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# Name: Age Group, Length: 19987, dtype: int64
# <ipython-input-26-01a2a95b9375>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age Group"]=le.fit_transform(df["Age Group"])

# %%
le= LabelEncoder()
df["Length of Stay"]=le.fit_transform(df["Length of Stay"])
print(df["Length of Stay"])
# Out:
# 0        20
# 1        42
# 2        20
# 3        20
# 4        31
#          ..
# 19994    42
# 19995    20
# 19996    20
# 19997    20
# 19998     0
# Name: Length of Stay, Length: 19987, dtype: int64
# <ipython-input-27-fd7c2f743862>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Length of Stay"]=le.fit_transform(df["Length of Stay"])

# %%
le= LabelEncoder()
df["Patient Disposition"]=le.fit_transform(df["Patient Disposition"])
df["Patient Disposition"]
# Out:
# <ipython-input-28-4944210687d5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Patient Disposition"]=le.fit_transform(df["Patient Disposition"])
# 0        5
# 1        1
# 2        5
# 3        5
# 4        5
#         ..
# 19994    5
# 19995    5
# 19996    5
# 19997    5
# 19998    5
# Name: Patient Disposition, Length: 19987, dtype: int64

# %%
le= LabelEncoder()
df["Source of Payment 1"]=le.fit_transform(df["Source of Payment 1"])
print(df["Source of Payment 1"])
# Out:
# 0        2
# 1        2
# 2        0
# 3        0
# 4        7
#         ..
# 19994    2
# 19995    0
# 19996    2
# 19997    2
# 19998    2
# Name: Source of Payment 1, Length: 19987, dtype: int64
# <ipython-input-29-84f084278031>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Source of Payment 1"]=le.fit_transform(df["Source of Payment 1"])

# %%
df.head()
# Out:
#    Facility ID  Age Group  Length of Stay  Type of Admission  \
# 0       1458.0          0              20                  2
# 1       1458.0          0              42                  1
# 2       1464.0          0              20                  2
# 3        977.0          0              20                  2
# 4       1176.0          0              31                  1
#
#    Patient Disposition  CCS Procedure Description  \
# 0                    5                         22
# 1                    1                        171
# 2                    5                         94
# 3                    5                        163
# 4                    5                         32
#
#    APR Severity of Illness Code  APR Risk of Mortality  Source of Payment 1
# 0                             1                      2                    2
# 1                             2                      1                    2
# ...

# %%
df.tail()
# Out:
#        Facility ID  Age Group  Length of Stay  Type of Admission  \
# 19994       1456.0          0              42                  2
# 19995       1456.0          0              20                  2
# 19996       1456.0          0              20                  2
# 19997       1456.0          0              20                  2
# 19998       1456.0          0               0                  2
#
#        Patient Disposition  CCS Procedure Description  \
# 19994                    5                         94
# 19995                    5                        154
# 19996                    5                         94
# 19997                    5                         94
# 19998                    5                         94
#
#        APR Severity of Illness Code  APR Risk of Mortality  \
# 19994                             1                      2
# 19995                             1                      2
# 19996                             1                      2
# ...

# %%
sns.pairplot(df,hue="Type of Admission")

# %%
df.corr()
# Out:
#                               Facility ID  Age Group  Length of Stay  \
# Facility ID                      1.000000  -0.055265       -0.004008
# Age Group                       -0.055265   1.000000        0.041048
# Length of Stay                  -0.004008   0.041048        1.000000
# Type of Admission                0.127990  -0.207978        0.047630
# Patient Disposition             -0.018105   0.195087        0.037404
# CCS Procedure Description        0.061916  -0.016675        0.019314
# APR Severity of Illness Code    -0.086211   0.173660        0.239075
# APR Risk of Mortality           -0.015239   0.018946        0.034374
# Source of Payment 1              0.044374   0.163052        0.012942
#
#                               Type of Admission  Patient Disposition  \
# Facility ID                            0.127990            -0.018105
# Age Group                             -0.207978             0.195087
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(x="Type of Admission",y="CCS Procedure Description",data=df)
# Out:
# <Axes: xlabel='Type of Admission', ylabel='CCS Procedure Description'>

# %%
features = df.iloc[:,1:10]
features_sum = np.array(features.sum())
plt.pie(features_sum,explode= (.1,.1,.1,.1,.1,.1,.1,.1),labels=features.columns,autopct = '{:.2f}%'.format)
plt.legend(loc='lower left')
plt.show()

# %%
plot = sns.FacetGrid(df, hue="Type of Admission")
plot.map(sns.distplot, "Age Group").add_legend()

plot = sns.FacetGrid(df, hue="Type of Admission")
plot.map(sns.distplot, "Length of Stay").add_legend()

plot = sns.FacetGrid(df, hue="Type of Admission")
plot.map(sns.distplot, "Patient Disposition").add_legend()

plot = sns.FacetGrid(df, hue="Type of Admission")
plot.map(sns.distplot, "APR Severity of Illness Code").add_legend()

plot = sns.FacetGrid(df, hue="Type of Admission")
plot.map(sns.distplot, "APR Risk of Mortality").add_legend()

plot = sns.FacetGrid(df, hue="Type of Admission")
plot.map(sns.distplot, "Source of Payment 1").add_legend()

plot = sns.FacetGrid(df, hue="Type of Admission")
plot.map(sns.distplot, "Facility ID").add_legend()

plot = sns.FacetGrid(df, hue="Type of Admission")
plot.map(sns.distplot, "CCS Procedure Description").add_legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
x = df.drop(['Type of Admission'],axis = 1)
y = df['Type of Admission']

# %%
y=np.array(y).reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .2,random_state =42)

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %%
logmodel1 = LogisticRegression()

# %%
logmodel1.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred1 =logmodel1.predict(x_test)

# %%
# calculate accuracy#
print("Training set accuracy: {:.3f}".format(logmodel1.score(x_train, y_train)))
print("Test set accuracy: {:.3f}".format(logmodel1.score(x_test, y_test)))
print(accuracy_score(y_test,y_pred1))
# Out:
# Training set accuracy: 0.640
# Test set accuracy: 0.643
# 0.6433216608304152

# %%
print(confusion_matrix(y_test,y_pred1))
# Out:
# [[   0    7  241    0    0]
#  [   0   14 1096    0    0]
#  [   0    9 2558    0    0]
#  [   0    0    1    0    0]
#  [   0    0   72    0    0]]

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       248
#            1       0.47      0.01      0.02      1110
#            2       0.64      1.00      0.78      2567
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        72
#
#     accuracy                           0.64      3998
#    macro avg       0.22      0.20      0.16      3998
# weighted avg       0.54      0.64      0.51      3998
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(accuracy_score(y_test,y_pred1))
# Out:
# 0.6433216608304152

# %% [markdown]
# **with minmaxscaling**

# %%
from sklearn.preprocessing import MinMaxScaler
scalerx = MinMaxScaler()
x_train_scaled = scalerx.fit_transform(x_train)
x_test_scaled = scalerx.fit_transform(x_test)

# %%
logmodel2 = LogisticRegression()

# %%
logmodel2.fit(x_train_scaled,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred2 =logmodel2.predict(x_test_scaled)

# %%
# calculate accuracy#
print("Training set accuracy: {:.3f}".format(logmodel1.score(x_train_scaled, y_train)))
print("Test set accuracy: {:.3f}".format(logmodel1.score(x_test_scaled, y_test)))
print(accuracy_score(y_test,y_pred2))
# Out:
# Training set accuracy: 0.272
# Test set accuracy: 0.278
# 0.6725862931465733
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
confusion_matrix(y_test,y_pred2)
# Out:
# array([[  13,  120,  115,    0,    0],
#        [  20,  249,  841,    0,    0],
#        [   0,  140, 2427,    0,    0],
#        [   0,    0,    1,    0,    0],
#        [   3,   25,   44,    0,    0]])

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.05      0.09       248
#            1       0.47      0.22      0.30      1110
#            2       0.71      0.95      0.81      2567
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        72
#
#     accuracy                           0.67      3998
#    macro avg       0.31      0.24      0.24      3998
# weighted avg       0.61      0.67      0.61      3998
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(accuracy_score(y_test,y_pred2))
# Out:
# 0.6725862931465733

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %%
Tree = DecisionTreeClassifier()
Tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy on training set: {:.3f}".format(Tree.score(x_train, y_train)))
print("Accuracy on test set: {:.3f}".format(Tree.score(x_test, y_test)))
# Out:
# Accuracy on training set: 0.974
# Accuracy on test set: 0.883

# %%
Tree = DecisionTreeClassifier(max_depth=2, random_state=2021)
Tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=2021)

# %%
print("Accuracy on training set: {:.3f}".format(Tree.score(x_train, y_train)))
print("Accuracy on test set: {:.3f}".format(Tree.score(x_test, y_test)))
# Out:
# Accuracy on training set: 0.700
# Accuracy on test set: 0.693

# %%
y_pred=Tree.predict(x_test)

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[  65   81  102    0    0]
#  [  76  291  743    0    0]
#  [   0  154 2413    0    0]
#  [   0    1    0    0    0]
#  [  15   10   47    0    0]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.26      0.32       248
#            1       0.54      0.26      0.35      1110
#            2       0.73      0.94      0.82      2567
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        72
#
#     accuracy                           0.69      3998
#    macro avg       0.34      0.29      0.30      3998
# weighted avg       0.65      0.69      0.65      3998
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6925962981490745

# %%
import graphviz
from sklearn import tree
tree.plot_tree(Tree,
               feature_names=x_train.columns,
               filled=True,fontsize=5)
# Out:
# [Text(0.5, 0.8333333333333334, 'Length of Stay <= 19.5\ngini = 0.514\nsamples = 15989\nvalue = [1032, 4343, 10207, 5, 402]'),
#  Text(0.25, 0.5, 'Facility ID <= 1465.0\ngini = 0.628\nsamples = 2695\nvalue = [404, 1377, 795, 2, 117]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.604\nsamples = 2196\nvalue = [374, 1219, 526, 2, 75]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.598\nsamples = 499\nvalue = [30, 158, 269, 0, 42]'),
#  Text(0.75, 0.5, 'Age Group <= 0.5\ngini = 0.446\nsamples = 13294\nvalue = [628, 2966, 9412, 3, 285]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.397\nsamples = 12616\nvalue = [330, 2680, 9412, 3, 191]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.61\nsamples = 678\nvalue = [298, 286, 0, 0, 94]')]

# %% [markdown]
# Feature importance in Decision trees

# %%
print("Feature importances:\n{}".format(Tree.feature_importances_))
# Out:
# Feature importances:
# [0.05631541 0.43470679 0.5089778  0.         0.         0.
#  0.         0.        ]

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=2021)
rf.fit(x_train, y_train)
# Out:
# <ipython-input-68-6bf7db324b7a>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train, y_train)
# RandomForestClassifier(random_state=2021)

# %%
print("Accuracy on training set: {:.3f}".format(rf.score(x_train, y_train)))
print("Accuracy on test set: {:.3f}".format(rf.score(x_test, y_test)))
# Out:
# Accuracy on training set: 0.974
# Accuracy on test set: 0.888

# %%
rf1 = RandomForestClassifier(max_depth=3, n_estimators=100, random_state=2021)
rf1.fit(x_train, y_train)
# Out:
# <ipython-input-70-03fd15caa8e5>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf1.fit(x_train, y_train)
# RandomForestClassifier(max_depth=3, random_state=2021)

# %%
print("Accuracy on training set: {:.3f}".format(rf1.score(x_train, y_train)))
print("Accuracy on test set: {:.3f}".format(rf1.score(x_test, y_test)))
# Out:
# Accuracy on training set: 0.702
# Accuracy on test set: 0.702

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 127  108   12    0    1]
#  [  51  938  105    0   16]
#  [   4   99 2462    0    2]
#  [   0    1    0    0    0]
#  [  10   26   12    0   24]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.51      0.58       248
#            1       0.80      0.85      0.82      1110
#            2       0.95      0.96      0.95      2567
#            3       0.00      0.00      0.00         1
#            4       0.56      0.33      0.42        72
#
#     accuracy                           0.89      3998
#    macro avg       0.59      0.53      0.55      3998
# weighted avg       0.88      0.89      0.88      3998
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8881940970485243

# %% [markdown]
# **knn**

# %%
from sklearn.neighbors import KNeighborsClassifier

training_accuracy = []
test_accuracy = []
# try n_neighbors from 1 to 10
neighbors_settings = range(1, 11)

for n_neighbors in neighbors_settings:
    # build the model
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn.fit(x_train, y_train)
    # record training set accuracy
    training_accuracy.append(knn.score(x_train, y_train))
    # record test set accuracy
    test_accuracy.append(knn.score(x_test, y_test))

plt.plot(neighbors_settings, training_accuracy, label="training accuracy")
plt.plot(neighbors_settings, test_accuracy, label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()
plt.savefig('knn_compare_model')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[ 119   92   34    0    3]
#  [  73  879  149    0    9]
#  [  13  134 2416    0    4]
#  [   0    1    0    0    0]
#  [  10   25   18    0   19]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.48      0.51       248
#            1       0.78      0.79      0.78      1110
#            2       0.92      0.94      0.93      2567
#            3       0.00      0.00      0.00         1
#            4       0.54      0.26      0.36        72
#
#     accuracy                           0.86      3998
#    macro avg       0.56      0.50      0.52      3998
# weighted avg       0.85      0.86      0.85      3998
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8586793396698349

# %% [markdown]
# **SVM = Support Vector Machine**

# %%
y_train=y_train.ravel()

# %%
from sklearn.preprocessing import MinMaxScaler
scalerx = MinMaxScaler()
x_train_scaled = scalerx.fit_transform(x_train)
x_test_scaled = scalerx.fit_transform(x_test)

# %%
from sklearn import svm
from sklearn.svm import SVC

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score

# %%
svc = SVC()
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
print("Accuracy on training set: {:.2f}".format(svc.score(x_train, y_train)))
print("Accuracy on test set: {:.2f}".format(svc.score(x_test, y_test)))
# Out:
# Accuracy on training set: 0.64
# Accuracy on test set: 0.64

# %%
prediction = svc.predict(x_test)

# %%
print(accuracy_score(y_test, prediction))
# Out:
# 0.6418209104552276

# %%
svc = SVC()
svc.fit(x_train_scaled, y_train)

print("Accuracy on training set: {:.2f}".format(svc.score(x_train_scaled, y_train)))
print("Accuracy on test set: {:.2f}".format(svc.score(x_test_scaled, y_test)))
# Out:
# Accuracy on training set: 0.73
# Accuracy on test set: 0.72

# %%
prediction = svc.predict(x_test_scaled)

# %%
print(accuracy_score(y_test, prediction))
# Out:
# 0.7196098049024512

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[  50,  129,   69,    0,    0],
#        [  25,  446,  639,    0,    0],
#        [   0,  186, 2381,    0,    0],
#        [   0,    0,    1,    0,    0],
#        [  13,   23,   36,    0,    0]])

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.20      0.30       248
#            1       0.57      0.40      0.47      1110
#            2       0.76      0.93      0.84      2567
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        72
#
#     accuracy                           0.72      3998
#    macro avg       0.38      0.31      0.32      3998
# weighted avg       0.68      0.72      0.69      3998
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# **Neural Network**

# %%
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 47, stratify=y)

# %%
from sklearn.preprocessing import MinMaxScaler
scalerx = MinMaxScaler()
x_train_scaled = scalerx.fit_transform(x_train)
x_test_scaled = scalerx.fit_transform(x_test)

# %%
import tensorflow as tf
from keras.models import Sequential # It is linear stack of layers)
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(4, activation = 'relu', input_shape=(x_train_scaled.shape[1], )),   #
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 4)                 36
#
#  dense_1 (Dense)             (None, 1)                 5
#
# ...
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.variables
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(8, 4) dtype=float32, numpy=
#  array([[-0.14518642,  0.05934983,  0.57262915, -0.68471885],
#         [-0.02223164, -0.21253946,  0.02904236,  0.07858682],
#         [ 0.25547922,  0.24461544,  0.14766687, -0.06078112],
#         [-0.633028  ,  0.51200753, -0.01889646,  0.24721014],
#         [-0.27365407, -0.42792505,  0.08179116, -0.41529465],
#         [-0.6347175 ,  0.60276824, -0.35630828,  0.5591304 ],
#         [ 0.1511057 ,  0.12905145,  0.6229264 ,  0.39589733],
#         [-0.3630184 ,  0.02131045,  0.42404467, -0.26800507]],
#        dtype=float32)>,
#  <tf.Variable 'dense/bias:0' shape=(4,) dtype=float32, numpy=array([0., 0., 0., 0.], dtype=float32)>,
#  <tf.Variable 'dense_1/kernel:0' shape=(4, 1) dtype=float32, numpy=
#  array([[ 0.07104182],
#         [ 0.12375045],
#         [ 0.67326784],
#         [-0.33168715]], dtype=float32)>,
#  <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %%
# Compiling the ANN
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fitting the ANN to the Training set
history = model.fit(x_train_scaled, y_train, batch_size=32, epochs=10, validation_data=(x_test_scaled, y_test))
# Out:
# Epoch 1/10
# 500/500 [==============================] - 2s 3ms/step - loss: -1.7261 - accuracy: 0.2728 - val_loss: -4.5976 - val_accuracy: 0.2729
# Epoch 2/10
# 500/500 [==============================] - 1s 2ms/step - loss: -9.9457 - accuracy: 0.2728 - val_loss: -16.5706 - val_accuracy: 0.2729
# Epoch 3/10
# 500/500 [==============================] - 1s 2ms/step - loss: -25.4716 - accuracy: 0.2728 - val_loss: -35.4490 - val_accuracy: 0.2729
# Epoch 4/10
# 500/500 [==============================] - 1s 2ms/step - loss: -47.3899 - accuracy: 0.2728 - val_loss: -60.2534 - val_accuracy: 0.2729
# Epoch 5/10
# 500/500 [==============================] - 1s 2ms/step - loss: -74.8169 - accuracy: 0.2728 - val_loss: -90.1859 - val_accuracy: 0.2729
# Epoch 6/10
# 500/500 [==============================] - 1s 2ms/step - loss: -107.1895 - accuracy: 0.2728 - val_loss: -124.8918 - val_accuracy: 0.2729
# Epoch 7/10
# ...

# %%
#now testing for Test data
y_pred = model.predict(x_test_scaled)
# Out:
# 125/125 [==============================] - 0s 1ms/step

# %%
print(y_pred)
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.2728864432216108

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[  11,   45,  200,    0,    0],
#        [  22,  219,  850,    0,    0],
#        [  54,  509, 1992,    0,    0],
#        [   0,    0,    1,    0,    0],
#        [   1,   11,   83,    0,    0]])

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.12      0.04      0.06       256
#            1       0.28      0.20      0.23      1091
#            2       0.64      0.78      0.70      2555
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        95
#
#     accuracy                           0.56      3998
#    macro avg       0.21      0.20      0.20      3998
# weighted avg       0.49      0.56      0.52      3998
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# **ACCURACY OF DIFFERENT MACHINE LEARNING ALGORITHMS**
#
# 1.   Logistic Regression :- 0.67
# 2.   Decision Tree :- 0.69
# 3.   Random Forest :- 0.89
# 4.   KNN :- 0.86
# 5.   SVM :- 0.72
# 6.   Neural Network :- 0.27
#
# So, the best accuracy score of machine learning algorithm on the ***sparcs dataset*** is ***RANDOM FOREST*** (0.89).
